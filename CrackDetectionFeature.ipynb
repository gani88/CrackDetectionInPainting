# %%
import cv2
import numpy as np

# Read the input image
img = cv2.imread("angel4.jpg", cv2.IMREAD_GRAYSCALE)

# Define the kernel size for the opening operation
kernel_size = 10

# Define the structuring element for the opening operation
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the opening operation to remove small details and noise
opened = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# Subtract the opened image from the original image to obtain the top-hat transform
tophat = cv2.subtract(img, opened)

# Save the output image
cv2.imwrite("output_image.png", tophat)
# Out:
# True

# %%
import cv2
import numpy as np

# Read the input image
img = cv2.imread("angel4.jpg", cv2.IMREAD_GRAYSCALE)

# Define the kernel size for the dilation operation
kernel_size = 3

# Define the structuring element for the dilation operation
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the dilation operation to expand the boundaries of the cracks
dilated = cv2.dilate(img, kernel)

# Save the output image
cv2.imwrite("output_image_dilated.png", dilated)
# Out:
# True

# %%
import cv2
import numpy as np

# Read the input image
img = cv2.imread("8jerome.jpg", cv2.IMREAD_GRAYSCALE)

# Define the kernel size for the top-hat transform
kernel_size = 10

# Define the structuring element for the top-hat transform
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the top-hat transform to enhance the contrast of the cracks
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# Define the kernel size for the dilation operation
kernel_size = 3

# Define the structuring element for the dilation operation
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the dilation operation to expand the boundaries of the cracks
dilated = cv2.dilate(tophat, kernel)

# Save the output image
cv2.imwrite("output_image_combined.png", dilated)
# Out:
# True

# %%
import cv2
import numpy as np

# Read the input image
img = cv2.imread("8jerome.jpg", cv2.IMREAD_GRAYSCALE)

# Define the kernel size for the top-hat transform
kernel_size = 10

# Define the structuring element for the top-hat transform
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the top-hat transform to enhance the contrast of the cracks
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# Define the kernel size for the dilation operation
kernel_size = 3

# Define the structuring element for the dilation operation
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the dilation operation to expand the boundaries of the cracks
dilated = cv2.dilate(tophat, kernel)

# Find the contours of the cracks
contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw a bounding box around each contour
for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)

# Save the output image
cv2.imwrite("combined_box.png", img)
# Out:
# True

# %%
import cv2
import numpy as np

# Read the input image
img = cv2.imread("8jerome.jpg", cv2.IMREAD_GRAYSCALE)

# Define the kernel size for the top-hat transform
kernel_size = 10

# Define the structuring element for the top-hat transform
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the top-hat transform to enhance the contrast of the cracks
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# Define the kernel size for the dilation operation
kernel_size = 3

# Define the structuring element for the dilation operation
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

# Perform the dilation operation to expand the boundaries of the cracks
dilated = cv2.dilate(tophat, kernel)

# Threshold the image to create a binary mask of the cracks
_, thresh = cv2.threshold(dilated, 10, 255, cv2.THRESH_BINARY)

# Find the contours of the cracks
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw a bounding box around each contour
for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)

# Save the output image
cv2.imwrite("improved_threshold.png", img)
# Out:
# True
